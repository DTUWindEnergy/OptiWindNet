# %% [markdown]
# ## Cables

# %% [markdown]
# [Try this yourself](https://colab.research.google.com/github/DTUWindEnergy/TopFarm2/blob/master/docs/notebooks/cables.ipynb) (requires google account)

# %% [markdown]
# TOPFARM can use the Electrical Network Design package EDWIN to optimize the carray cabels as well as the substation position at each iteration of the layout optimization

# %% [markdown]
# ### Import

# %%
import numpy as np
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt

from topfarm.constraint_components.spacing import SpacingConstraint
from topfarm.constraint_components.boundary import XYBoundaryConstraint
from topfarm.easy_drivers import EasyScipyOptimizeDriver
from topfarm.cost_models.cost_model_wrappers import CostModelComponent
from topfarm._topfarm import TopFarmProblem, TopFarmGroup
from topfarm.cost_models.py_wake_wrapper import PyWakeAEPCostModelComponent
from topfarm.plotting import XYPlotComp
from topfarm.utils import plot_list_recorder
from topfarm.cost_models.economic_models.dtu_wind_cm_main import economic_evaluation

from py_wake.examples.data.iea37._iea37 import IEA37_WindTurbines
from py_wake import BastankhahGaussian
from py_wake.examples.data.hornsrev1 import Hornsrev1Site

from optiwindnet.api import WindFarmNetwork, Heuristic, MILP
# Out:
# load c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\ortools\.libs\zlib1.dll...
# load c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\ortools\.libs\abseil_dll.dll...
# load c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\ortools\.libs\utf8_validity.dll...
# load c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\ortools\.libs\re2.dll...
# load c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\ortools\.libs\libprotobuf.dll...
# load c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\ortools\.libs\highs.dll...
# load c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\ortools\.libs\ortools.dll...

# %% [markdown]
# ### Site

# %%
n_wt = 30
initial = np.asarray([np.random.random(30)*6000, np.random.random(30)*-10000]).T
x_init = initial[:,0]
y_init = initial[:,1]
boundary = np.array([(0, 0), (6000, 0), (6000, -10000), (0, -10000)])  # turbine boundaries
drivers = [EasyScipyOptimizeDriver(maxiter=10)]
windTurbines = IEA37_WindTurbines()
site = Hornsrev1Site()
wfm = BastankhahGaussian(site, windTurbines)
# Out:
# c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\py_wake\deficit_models\gaussian.py:124: UserWarning: The BastankhahGaussian model is not representative of the setup used in the literature. For this, use py_wake.literature.gaussian_models.Bastankhah_PorteAgel_2014 instead
#   DeprecatedModel.__init__(self, 'py_wake.literature.gaussian_models.Bastankhah_PorteAgel_2014')

# %% [markdown]
# ### Bathymetry

# %%
sigma = 3000.0
mu = 0.0

x_peak_1 = 1000
y_peak_1 = -1000
x_peak_2 = 4000
y_peak_2 = -8000
x1, y1 = np.meshgrid(np.linspace(0 - x_peak_1, 6000- x_peak_1, 100), np.linspace(-10000 - y_peak_1, 0 - y_peak_1, 100))
d1 = np.sqrt(x1*x1 + y1*y1)
g1 = np.exp(-((d1 - mu)**2 / (2.0 * sigma**2)))
x2, y2 = np.meshgrid(np.linspace(0 - x_peak_2, 6000- x_peak_2, 100), np.linspace(-10000 - y_peak_2, 0 - y_peak_2, 100))
d2 = np.sqrt(x2*x2 + y2*y2)
g2 = np.exp(-((d2 - mu)**2 / (2.0 * sigma**2)))
g = 5 * g1 - 8 * g2 - 30

plt.imshow(g, extent=(-1000, 7000, -11000, 1000), origin='lower', cmap='viridis')
plt.colorbar()
plt.title('2D Gaussian Function')
plt.show()

x = np.linspace(-1000, 7000, 100)
y = np.linspace(-11000, 1000, 100)

f = RegularGridInterpolator((x, y), g)

# %% [markdown]
# ### Cables

# %%
x_ss_init = x_init.mean()
y_ss_init = y_init.mean()
turbines_pos=  np.column_stack((x_init, y_init))
substations_pos =  np.column_stack((x_ss_init, y_ss_init))

cables = np.array([(3, 100),(5, 150), (10, 250)])  # Here you set up cables [<cable cross section>, <number of turbines can be connected>, <price in € per meter>]


# 'obstacles' is an optional location attribute
obstacles = []

border =  np.array(
    [[-1000, -11000], [10000, -10000], [10000, 5000], [-1000, 5000]],
    dtype=float)

wfn = WindFarmNetwork(turbines=turbines_pos, substations=substations_pos, cables=cables, border=border, obstacles=obstacles)
router_pre_solver = Heuristic(solver='Esau_Williams')
res_pre_solver= wfn.optimize(router=router_pre_solver)
#G = wfn.optimize(turbines_pos)
cable_cost_ref = wfn.cost() # euro
cable_length_ref = wfn.length()  # m
cost_per_length_ref = cable_cost_ref / cable_length_ref # euro / m

wfn.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Economy

# %%
Drotor_vector = [windTurbines.diameter()] * n_wt
power_rated_vector = [float(windTurbines.power(20))*1e-6] * n_wt
hub_height_vector = [windTurbines.hub_height()] * n_wt

# add additional cost model inputs for shore distance, energy price, project lifetime, rated rotor speed and water depth
distance_from_shore = 30         # [km]
energy_price = 0.1               # [Euro/kWh] What we get per kWh
project_duration = 25            # [years]
rated_rpm_array = [12] * n_wt    # [rpm]
simres = wfm(x_init, y_init)
aep = simres.aep().values.sum()
CF = aep / (windTurbines.power(20)*1e-9 * 24*365*n_wt)

eco_eval = economic_evaluation(distance_from_shore, energy_price, project_duration)
npv_ref = eco_eval.calculate_npv(rated_rpm_array, Drotor_vector, power_rated_vector, hub_height_vector, 30, aep/n_wt * np.ones(n_wt)*10**6, cabling_cost=cable_cost_ref)

# %% [markdown]
# ### Python Functions

# %%
# Water Depth
def water_depth_func(x, y, **kwargs):
    xnew, ynew = np.meshgrid(x, y)
    points = np.array([xnew.flatten(), ynew.flatten()]).T
    return - np.diag(f(points).reshape(n_wt, n_wt).T)

# Cables
def cable_func(x, y, x_substation, y_substation, **kwargs):
    wfn.optimize(turbines= np.column_stack((x, y)), substations= np.column_stack((float(x_substation[0]), float(y_substation[0]))), router=router_pre_solver)
    return wfn.cost(), {'cabling_length': wfn.length(), 'terse_links': wfn.terse_links()}

# Economy
def npv_func(AEP, water_depth, cabling_cost, **kwargs):
    eco_eval.calculate_npv(rated_rpm_array, Drotor_vector, power_rated_vector, hub_height_vector, water_depth, AEP/n_wt * np.ones(n_wt)*10**6, cabling_cost=cabling_cost)
    eco_eval.calculate_irr(rated_rpm_array, Drotor_vector, power_rated_vector, hub_height_vector, water_depth, AEP/n_wt * np.ones(n_wt)*10**6, cabling_cost=cabling_cost)
    CAPEX = eco_eval.project_costs_sums["CAPEX"]
    OPEX = eco_eval.project_costs_sums["OPEX"]
    return eco_eval.NPV, {'irr': eco_eval.IRR,
                          'OPEX': OPEX,
                          'CAPEX': CAPEX,}

# %% [markdown]
# ### Components

# %%
# Water Depth
water_depth_component = CostModelComponent(input_keys=[('x', x_init),('y', y_init)],
                                          n_wt=n_wt,
                                          cost_function=water_depth_func,
                                          objective=False,
                                          output_keys=[('water_depth', np.zeros(n_wt))])

# Cables
cable_component = CostModelComponent(input_keys=[('x', x_init),('y', y_init), ('x_substation', x_ss_init), ('y_substation', y_ss_init)],
                                     n_wt=n_wt,
                                     cost_function=cable_func,
                                     objective=False,
                                     output_keys=[('cabling_cost', 0)],
                                     additional_output = [
                                                ('cabling_length', 0.0),
                                                ('terse_links', np.zeros((30,)))
                                                ])

# Economy
npv_comp = CostModelComponent(input_keys=[('AEP', 0), ('water_depth', 30*np.ones(n_wt)), ('cabling_cost', 100000)],
                              n_wt=n_wt,
                              cost_function=npv_func,
                              objective=True,
                              maximize=True,
                              output_keys=[('npv', 0)],
                              additional_output=[('irr', 0),
                                                 ('CAPEX', 0),
                                                 ('OPEX', 0)])

# AEP
aep_comp = PyWakeAEPCostModelComponent(wfm, n_wt, objective=False)

# %% [markdown]
# ### Problem Assembly

# %%
cost_comp = TopFarmGroup([PyWakeAEPCostModelComponent(wfm, n_wt, objective=False), water_depth_component, cable_component, npv_comp])


tf = TopFarmProblem(
    design_vars=dict(zip('xy', initial.T), x_substation=x_ss_init, y_substation=y_ss_init),
    cost_comp=cost_comp,
    constraints=[XYBoundaryConstraint(boundary),
                 SpacingConstraint(500)
                 ],
    driver=drivers[0],
    plot_comp=XYPlotComp()
)
# Out:
# INFO: checking out_of_order...
# INFO:     out_of_order check complete (0.000582 sec).
# INFO: checking system...
# INFO:     system check complete (0.000023 sec).
# INFO: checking solvers...
# INFO:     solvers check complete (0.000271 sec).
# INFO: checking dup_inputs...
# INFO:     dup_inputs check complete (0.000041 sec).
# INFO: checking missing_recorders...
# INFO:     missing_recorders check complete (0.000006 sec).
# INFO: checking unserializable_options...
# INFO:     unserializable_options check complete (0.000316 sec).
# INFO: checking comp_has_no_outputs...
# INFO:     comp_has_no_outputs check complete (0.000250 sec).
# INFO: checking auto_ivc_warnings...
# INFO:     auto_ivc_warnings check complete (0.000006 sec).

# %% [markdown]
# ### Optimize

# %%
cost, _, recorder = tf.optimize()
# Out:
# INFO: checking out_of_order...
# INFO:     out_of_order check complete (0.000218 sec).
# INFO: checking system...
# INFO:     system check complete (0.000025 sec).
# INFO: checking solvers...
# INFO:     solvers check complete (0.000609 sec).
# INFO: checking dup_inputs...
# INFO:     dup_inputs check complete (0.000075 sec).
# INFO: checking missing_recorders...
# INFO:     missing_recorders check complete (0.000007 sec).
# INFO: checking unserializable_options...
# INFO:     unserializable_options check complete (0.000550 sec).
# INFO: checking comp_has_no_outputs...
# INFO:     comp_has_no_outputs check complete (0.000064 sec).
# INFO: checking auto_ivc_warnings...
# INFO:     auto_ivc_warnings check complete (0.000004 sec).
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\system.py:2931, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2930 try:
# -> 2931     yield
#    2932 except Exception:
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\explicitcomponent.py:281, in ExplicitComponent._compute_wrapper(self)
#     280 else:
# --> 281     self.compute(self._inputs, self._outputs)
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\topfarm\cost_models\cost_model_wrappers.py:166, in CostModelComponent.compute(self, inputs, outputs)
#     165 if self.additional_output:
# --> 166     c, additional_output = self.cost_function(**{x: inputs[x] for x in self.all_input_keys})
#     167     for k, v in additional_output.items():
#
# Cell In[6], line 9, in cable_func(x, y, x_substation, y_substation, **kwargs)
#       8 def cable_func(x, y, x_substation, y_substation, **kwargs):
# ----> 9     wfn.optimize(turbines= np.column_stack((x, y)), substations= np.column_stack((float(x_substation[0]), float(y_substation[0]))), router=router_pre_solver)
#      10     return wfn.cost(), {'cabling_length': wfn.length(), 'terse_links': wfn.terse_links()}
#
# File C:\code\OptiWindNet\optiwindnet\api.py:478, in WindFarmNetwork.optimize(self, turbines, substations, verbose, router)
#     477 if turbines is not None or substations is not None:
# --> 478     self._set_coordinates(turbines=turbines, substations=substations, verbose=False)
#     479     self._P, self._A = make_planar_embedding(self.L)
#
# File C:\code\OptiWindNet\optiwindnet\api.py:404, in WindFarmNetwork._set_coordinates(self, turbines, substations, verbose)
#     403 coord_u = VertexC[u, :]
# --> 404 coord_v = VertexC[v, :]
#     405 data['length'] = np.linalg.norm(np.array(coord_u) - np.array(coord_v))
#
# IndexError: index 35 is out of bounds for axis 0 with size 35
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cost, _, recorder = tf.optimize()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\topfarm\_topfarm.py:500, in TopFarmProblem.optimize(self, state, disp, recorder_as_list)
#     498 self.setup()
#     499 t = time.time()
# --> 500 self.run_driver()
#     501 self.cleanup()
#     502 if disp:
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\problem.py:749, in Problem.run_driver(self, case_prefix, reset_iter_counts)
#     745     record_model_options(self, self._run_counter)
#     747     model._clear_iprint()
# --> 749     return driver._run()
#     750 finally:
#     751     self._recording_iter.prefix = old_prefix
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\driver.py:822, in Driver._run(self)
#     820 else:
#     821     with SaveOptResult(self):
# --> 822         self.result.success = not self.run()
#     824 return self.result
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\drivers\scipy_optimizer.py:268, in ScipyOptimizeDriver.run(self)
#     266 with RecordingDebugging(self._get_name(), self.iter_count, self):
#     267     with model._relevance.nonlinear_active('iter'):
# --> 268         self._run_solve_nonlinear()
#     269     self.iter_count += 1
#     271 self._con_cache = self.get_constraint_values()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\driver.py:177, in DriverResult.track_stats.<locals>._track_time.<locals>.wrapper(*args, **kwargs)
#     174 @functools.wraps(func)
#     175 def wrapper(*args, **kwargs):
#     176     start_time = time.perf_counter()
# --> 177     ret = func(*args, **kwargs)
#     178     end_time = time.perf_counter()
#     179     result = args[0].result
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\driver.py:1268, in Driver._run_solve_nonlinear(self)
#    1266 @DriverResult.track_stats(kind='model')
#    1267 def _run_solve_nonlinear(self):
# -> 1268     return self._problem().model.run_solve_nonlinear()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\system.py:4963, in System.run_solve_nonlinear(self)
#    4957 """
#    4958 Compute outputs.
#    4959
#    4960 This calls _solve_nonlinear, but with the model assumed to be in an unscaled state.
#    4961 """
#    4962 with self._scaled_context_all():
# -> 4963     self._solve_nonlinear()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\group.py:3661, in Group._solve_nonlinear(self)
#    3659 with Recording(name + '._solve_nonlinear', self.iter_count, self):
#    3660     with self._relevance.active(self._nonlinear_solver.use_relevance()):
# -> 3661         self._nonlinear_solver._solve_with_cache_check()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\solvers\nonlinear\nonlinear_runonce.py:26, in NonlinearRunOnce._solve_with_cache_check(self)
#      25 def _solve_with_cache_check(self):
# ---> 26     self.solve()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\solvers\nonlinear\nonlinear_runonce.py:45, in NonlinearRunOnce.solve(self)
#      41             subsys._solve_nonlinear()
#      43 # If this is not a parallel group, transfer for each subsystem just prior to running it.
#      44 else:
# ---> 45     self._gs_iter()
#      47 rec.abs = 0.0
#      48 rec.rel = 0.0
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\solvers\solver.py:900, in NonlinearSolver._gs_iter(self)
#     898 if subsys._is_local:
#     899     try:
# --> 900         subsys._solve_nonlinear()
#     901     except AnalysisError as err:
#     902         if 'reraise_child_analysiserror' not in self.options or \
#     903                 self.options['reraise_child_analysiserror']:
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\group.py:3661, in Group._solve_nonlinear(self)
#    3659 with Recording(name + '._solve_nonlinear', self.iter_count, self):
#    3660     with self._relevance.active(self._nonlinear_solver.use_relevance()):
# -> 3661         self._nonlinear_solver._solve_with_cache_check()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\solvers\nonlinear\nonlinear_runonce.py:26, in NonlinearRunOnce._solve_with_cache_check(self)
#      25 def _solve_with_cache_check(self):
# ---> 26     self.solve()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\solvers\nonlinear\nonlinear_runonce.py:45, in NonlinearRunOnce.solve(self)
#      41             subsys._solve_nonlinear()
#      43 # If this is not a parallel group, transfer for each subsystem just prior to running it.
#      44 else:
# ---> 45     self._gs_iter()
#      47 rec.abs = 0.0
#      48 rec.rel = 0.0
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\solvers\solver.py:900, in NonlinearSolver._gs_iter(self)
#     898 if subsys._is_local:
#     899     try:
# --> 900         subsys._solve_nonlinear()
#     901     except AnalysisError as err:
#     902         if 'reraise_child_analysiserror' not in self.options or \
#     903                 self.options['reraise_child_analysiserror']:
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\explicitcomponent.py:307, in ExplicitComponent._solve_nonlinear(self)
#     305 with self._unscaled_context(outputs=[self._outputs], residuals=[self._residuals]):
#     306     self._residuals.set_val(0.0)
# --> 307     self._compute_wrapper()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\explicitcomponent.py:261, in ExplicitComponent._compute_wrapper(self)
#     257 def _compute_wrapper(self):
#     258     """
#     259     Call compute based on the value of the "run_root_only" option.
#     260     """
# --> 261     with self._call_user_function('compute'):
#     262         if self._run_root_only():
#     263             if self.comm.rank == 0:
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\system.py:2937, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2935         raise
#    2936     else:
# -> 2937         raise err_type(
#    2938             f"{self.msginfo}: Error calling {fname}(), {err}").with_traceback(trace)
#    2939 finally:
#    2940     self._inputs.read_only = False
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\system.py:2931, in System._call_user_function(self, fname, protect_inputs, protect_outputs, protect_residuals)
#    2928 self._residuals.read_only = protect_residuals
#    2930 try:
# -> 2931     yield
#    2932 except Exception:
#    2933     err_type, err, trace = sys.exc_info()
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\openmdao\core\explicitcomponent.py:281, in ExplicitComponent._compute_wrapper(self)
#     278     self.compute(self._inputs, self._outputs,
#     279                  self._discrete_inputs, self._discrete_outputs)
#     280 else:
# --> 281     self.compute(self._inputs, self._outputs)
#
# File c:\Users\amia\AppData\Local\miniconda3\envs\OptiWindNet\Lib\site-packages\topfarm\cost_models\cost_model_wrappers.py:166, in CostModelComponent.compute(self, inputs, outputs)
#     164 t = time.time()
#     165 if self.additional_output:
# --> 166     c, additional_output = self.cost_function(**{x: inputs[x] for x in self.all_input_keys})
#     167     for k, v in additional_output.items():
#     168         outputs[k] = v
#
# Cell In[6], line 9, in cable_func(x, y, x_substation, y_substation, **kwargs)
#       8 def cable_func(x, y, x_substation, y_substation, **kwargs):
# ----> 9     wfn.optimize(turbines= np.column_stack((x, y)), substations= np.column_stack((float(x_substation[0]), float(y_substation[0]))), router=router_pre_solver)
#      10     return wfn.cost(), {'cabling_length': wfn.length(), 'terse_links': wfn.terse_links()}
#
# File C:\code\OptiWindNet\optiwindnet\api.py:478, in WindFarmNetwork.optimize(self, turbines, substations, verbose, router)
#     476 # If new coordinates are provided, update them
#     477 if turbines is not None or substations is not None:
# --> 478     self._set_coordinates(turbines=turbines, substations=substations, verbose=False)
#     479     self._P, self._A = make_planar_embedding(self.L)
#     481 if turbines is None:
#
# File C:\code\OptiWindNet\optiwindnet\api.py:404, in WindFarmNetwork._set_coordinates(self, turbines, substations, verbose)
#     402 for u, v, data in self.G.edges(data=True):
#     403     coord_u = VertexC[u, :]
# --> 404     coord_v = VertexC[v, :]
#     405     data['length'] = np.linalg.norm(np.array(coord_u) - np.array(coord_v))
#     407 # Update cost
#
# IndexError: 'cost_comp.comp_2' <class CostModelComponent>: Error calling compute(), index 35 is out of bounds for axis 0 with size 35

# %% [markdown]
# ### Plot

# %%
plot_list_recorder(recorder)

# %%
print(wfn.S.edges(data='reverse'))
print(wfn._G_tentative.edges)

# %%
print(wfn.S.graph)
print(wfn._G_tentative.graph)

# %%
x_opt = recorder['x'][-1]
y_opt = recorder['y'][-1]
x_sub_opt = recorder['x_substation'][-1]
y_sub_opt = recorder['y_substation'][-1]
terse_links = recorder['terse_links'][-1]
print(terse_links)
wfn.G_from_terse_links(terse_links=terse_links, turbines=np.column_stack((x_opt, y_opt)), substations= np.column_stack((float(x_sub_opt), float(y_sub_opt))))

wfn.plot()

# %% [markdown]
# Compare the result with optimization

# %%
wfn.optimize(turbines=np.column_stack((x_opt, y_opt)), substations= np.column_stack((float(x_sub_opt), float(y_sub_opt))))

wfn.plot()
