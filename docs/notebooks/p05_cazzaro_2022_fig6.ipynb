# %% [markdown]
# ## 3.6.2 Cazzaro and Pisinger 2022 Fig. 6

# %% [markdown]
# **Concepts:** [Exact optimization](../routers.md#exact-optimization)

# %% [markdown]
# This is used in the paper **Flexible cable routing framework for wind farm collection system optimization**.

# %%
import pickle
from importlib.resources import files

from matplotlib import pyplot as plt

# %%
from optiwindnet.baselines.hgs import hgs_cvrp
from optiwindnet.importer import L_from_yaml
from optiwindnet.interarraylib import G_from_S
from optiwindnet.mesh import make_planar_embedding
from optiwindnet.MILP import ModelOptions, solver_factory
from optiwindnet.pathfinding import PathFinder
from optiwindnet.svg import svgplot, svgpplot

# %%
# %config InlineBackend.figure_formats = ['svg']
plt.rcParams['svg.fonttype'] = 'none'

# %% [markdown]
# ### Reference solution

# %% [markdown]
# Cazzaro, D., & Pisinger, D. (2022). Balanced cable routing for offshore wind farms with obstacles. Networks, 80(4), 386–406. https://doi.org/10.1002/net.22100

# %%
with open('data/cazzaro_2022_paper_routeset.pkl', 'rb') as f:
    G_ref = pickle.load(f)

# %%
svgplot(G_ref)
# Out:
# <SvgRepr[None]: name=cazzaro-2022; T=50; R=1; capacity=6
#  feeders = 9; C = 9; D = 6; Σλ = 9.9398 m; 6222 chars>

# %% [markdown]
# ### Start here

# %%
solver = solver_factory('gurobi')

# %%
L = L_from_yaml(files('optiwindnet.data') / 'Cazzaro-2022.yaml')

# %%
svgplot(L)
# Out:
# <SvgRepr[cazzaro_2022]: name=Cazzaro-2022; T=50; R=1; 2497 chars>

# %%
P, A = make_planar_embedding(L)

# %%
svgplot(A)
# Out:
# <SvgRepr[cazzaro_2022]: name=Cazzaro-2022; T=50; R=1; 11391 chars>

# %%
svgpplot(P, A)
# Out:
# <SvgRepr[cazzaro_2022]: name=Cazzaro-2022; T=50; R=1; 13357 chars>

# %% [markdown]
# ### Pre-solve

# %%
Sʹ = hgs_cvrp(A, capacity=6, time_limit=0.5, balanced=True)
Sʹ.graph['solution_time']
# Out:
# 0.2

# %%
Gʹ = G_from_S(Sʹ, A)
svgplot(Gʹ)
# Out:
# <SvgRepr[cazzaro_2022]: name=Cazzaro-2022; T=50; R=1; capacity=6; topology=radial
#  feeders = 9; C = 7; D = 0; Σλ = 9.6719 m; 5825 chars>

# %%
Hʹ = PathFinder(Gʹ, planar=P, A=A).create_detours()
svgplot(Hʹ)
# Out:
# <SvgRepr[cazzaro_2022]: name=Cazzaro-2022; T=50; R=1; capacity=6; topology=radial
#  feeders = 9; C = 7; D = 12; Σλ = 9.8049 m; 6392 chars>

# %%
1 - Hʹ.size(weight='length') / G_ref.size(weight='length')
# Out:
# 0.013578500078660682

# %%
solver.set_problem(
    P,
    A,
    capacity=6,
    model_options=ModelOptions(
        topology='radial',
        feeder_route='segmented',
        feeder_limit='minimum',
        balanced=True,
    ),
    warmstart=Sʹ,
)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 937681
# Set parameter MIPFocus to value 1
# Academic license 937681 - for non-commercial use only - registered to ma___@dtu.dk

# %%
solver.solve(
    mip_gap=0.005,
    time_limit=35,
    verbose=True,
    options={'mipfocus': 2, 'poolgap': 0.015, 'poolsearchmode': 2, 'poolsolutions': 20},
)
# Out:
# Set parameter MIPFocus to value 2
# Set parameter PoolGap to value 0.015
# Set parameter PoolSearchMode to value 2
# Set parameter PoolSolutions to value 20
# Set parameter TimeLimit to value 35
# Set parameter MIPGap to value 0.005
# Gurobi Optimizer version 13.0.2 build v13.0.2rc1 (linux64 - "Debian GNU/Linux forky/sid")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
#
#      0     0    9.44079    0  140    9.67192    9.44079  2.39%     -    1s
#      0     0    9.44138    0  141    9.67192    9.44138  2.38%     -    1s
#      0     0    9.44144    0  141    9.67192    9.44144  2.38%     -    1s
#      0     0    9.44801    0  133    9.67192    9.44801  2.32%     -    1s
#      0     0    9.44885    0  136    9.67192    9.44885  2.31%     -    1s
#      0     0    9.44896    0  136    9.67192    9.44896  2.31%     -    1s
#      0     0    9.45453    0  146    9.67192    9.45453  2.25%     -    1s
#      0     0    9.45567    0  145    9.67192    9.45567  2.24%     -    1s
#      0     0    9.45611    0  150    9.67192    9.45611  2.23%     -    1s
#      0     0    9.45618    0  151    9.67192    9.45618  2.23%     -    1s
#      0     0    9.45970    0  135    9.67192    9.45970  2.19%     -    1s
#      0     0    9.46011    0  134    9.67192    9.46011  2.19%     -    2s
#      0     0    9.46026    0  144    9.67192    9.46026  2.19%     -    2s
#      0     0    9.46445    0  141    9.67192    9.46445  2.15%     -    2s
#      0     0    9.46570    0  139    9.67192    9.46570  2.13%     -    2s
#      0     0    9.46623    0  139    9.67192    9.46623  2.13%     -    2s
#      0     0    9.46640    0  138    9.67192    9.46640  2.12%     -    2s
#      0     0    9.47090    0  144    9.67192    9.47090  2.08%     -    2s
#      0     0    9.47280    0  145    9.67192    9.47280  2.06%     -    2s
#      0     0    9.47306    0  146    9.67192    9.47306  2.06%     -    2s
#      0     0    9.47419    0  146    9.67192    9.47419  2.04%     -    2s
#      0     0    9.47431    0  146    9.67192    9.47431  2.04%     -    2s
#      0     0    9.47431    0  146    9.67192    9.47431  2.04%     -    2s
#      0     2    9.47431    0  146    9.67192    9.47431  2.04%     -    2s
#   1527  1429    9.61630   11   68    9.67192    9.52171  1.55%   105    5s
#   1648  1410    9.53380   15  117    9.67192    9.52636  1.50%   107   10s
#   7503  4509    9.74572   26   82    9.67192    9.63718  0.36%  93.3   15s
#
# Optimal solution found at node 12796 - now completing solution pool...
#
#     Nodes    |    Current Node    |      Pool Obj. Bounds     |     Work
#              |                    |   Worst                   |
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#  12796  8021     cutoff   23               -    9.67192      -  88.5   18s
#  15839  5547    9.72692   31   75    9.75868    9.67887  0.82%  82.7   20s
#
# Cutting planes:
#   Gomory: 13
#   Lift-and-project: 40
#   Cover: 21
#   Implied bound: 14
#   Projected implied bound: 5
#   MIR: 295
#   Mixing: 1
#   Flow cover: 250
#   GUB cover: 2
#   Inf proof: 1
#   Zero half: 11
#   Network: 30
#   RLT: 8
#   Relax-and-lift: 31
#   BQP: 3
#
# Explored 19242 nodes (1511914 simplex iterations) in 21.63 seconds (22.45 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 20: 9.67192 9.68346 9.69748 ... 9.73612
# No other solutions better than 9.73612
#
# Optimal solution found (tolerance 5.00e-03)
# Best objective 9.671920168636e+00, best bound 9.671920168636e+00, gap 0.0000%
# SolutionInfo(runtime=21.635385036468506, bound=9.671920168635916, objective=9.671920168635916, relgap=0.0, termination='optimal')

# %%
S, G = solver.get_solution()
svgplot(G)
# Out:
# <SvgRepr[cazzaro_2022]: name=Cazzaro-2022; T=50; R=1; capacity=6; topology=radial
#  feeders = 9; C = 7; D = 8; Σλ = 9.6967 m; 6236 chars>

# %%
1 - G.size(weight='length') / G_ref.size(weight='length')
# Out:
# 0.024457285866890444

# %%
with open('cazzaro_2022_comparison_κ_6_radial_balanced.pkl', 'wb') as outfile:
    pickle.dump(G, outfile)
