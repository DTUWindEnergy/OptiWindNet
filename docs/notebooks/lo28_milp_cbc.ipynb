# %% [markdown]
# ## CBC

# %% [markdown]
# **Concepts:** [Exact optimization](../routers.md#exact-optimization) **Reference:** [MILP Solvers](../reference/solvers.md) **Network/Router API:** [🎯 MILPRouter](hi23_milp.ipynb)

# %% [markdown]
# Solving the MILP model with COIN-OR CBC (open source). The approach and the full solver roster are described in [Exact optimization](../routers.md#exact-optimization), the model options in [Model options](../routers.md#model-options), and the installation steps in [Install](../install.md).

# %%
from optiwindnet.heuristics import constructor
from optiwindnet.importer import load_repository
from optiwindnet.interarraylib import G_from_S
from optiwindnet.mesh import make_planar_embedding
from optiwindnet.MILP import ModelOptions, solver_factory
from optiwindnet.svg import svgplot

# %% [markdown]
# ### Initialize Walney Extension

# %%
locations = load_repository()

# %%
L = locations.walneyext
capacity = 5

# %%
svgplot(L)
# Out:
# <SvgRepr[walneyext]: name=Walney Extension; T=87; R=2; 3625 chars>

# %% [markdown]
# ### Optimize Walney Extension

# %%
P, A = make_planar_embedding(L)

# %% [markdown]
# Initial heuristic solution to warm-start the solver:

# %%
Sʹ = constructor(A, capacity=capacity)
Gʹ = G_from_S(Sʹ, A)
svgplot(Gʹ)
# Out:
# <SvgRepr[walneyext]: name=Walney Extension; T=87; R=2; capacity=5; topology=branched
#  feeders = 9|11; C = 1; D = 0; Σλ = 136_145 m; 8592 chars>

# %%
solver = solver_factory('cbc')

# %%
solver.set_problem(
    P,
    A,
    capacity=Sʹ.graph['capacity'],
    model_options=ModelOptions(
        topology='branched',
        feeder_route='segmented',
        feeder_limit='unlimited',
    ),
    warmstart=Sʹ,
)

# %%
solver.solve(
    mip_gap=0.005,
    time_limit=150,
    verbose=True,
)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.13
# Build Date: Apr  1 2026
#
# command line - /usr/bin/cbc -threads 8 -timeMode elapsed -nodeStrategy downFewest -Dins on -VndVariableNeighborhoodSearch on -Rens on -mixedIntegerRoundingCuts on -flowCoverCuts on -cliqueCuts off -knapsackCuts off -zeroHalfCuts off -seconds 150 -ratioGap 0.005 -printingOptions all -import /home/masoda/tmp/tmpkwiy1hui.pyomo.lp -mipstart /home/masoda/tmp/tmp3v0luqcb.cbc.soln -stat=1 -solve -solu /home/masoda/tmp/tmpkwiy1hui.pyomo.soln (default strategy 1)
# threads was changed from 0 to 8
# Option for timeMode changed from cpu to elapsed
# Option for nodeStrategy changed from fewest to downfewest
# Option for Dins changed from off to on
# Option for VndVariableNeighborhoodSearch changed from off to on
# Option for Rens changed from off to on
# Option for mixedIntegerRoundingCuts changed from ifmove to on
# Option for flowCoverCuts changed from ifmove to on
# ...

# %%
S, G = solver.get_solution()

# %%
svgplot(G)
# Out:
# <SvgRepr[walneyext]: name=Walney Extension; T=87; R=2; capacity=5; topology=branched
#  feeders = 9|10; C = 0; D = 5; Σλ = 130_568 m; 8767 chars>
