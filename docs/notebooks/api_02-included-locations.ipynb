# %% [markdown]
# ## Included locations

# %%
from optiwindnet.api import WindFarmNetwork

# %% [markdown]
# Data of several locations is included in optiwindnet repository (data folder). We can see the list as:

# %%
from pathlib import Path

data_dir = Path('../../optiwindnet/data')
files = list(data_dir.glob('*'))  # Use '*.yaml' to filter by extension

for f in files:
    print(f.name)
# Out:
# Albatros.osm.pbf
# Amrumbank West.osm.pbf
# Anholt.yaml
# Arkona.osm.pbf
# Baltic 2.osm.pbf
# Baltic Eagle.osm.pbf
# BARD Offshore 1.osm.pbf
# Beatrice.osm.pbf
# Belwind.osm.pbf
# Borkum Riffgrund 1.yaml
# Borkum Riffgrund 2.yaml
# Borssele.yaml
# Butendiek.yaml
# Cazzaro-2022.yaml
# Cazzaro-2022G-140.yaml
# Cazzaro-2022G-210.yaml
# CECEP Yangjiang Nanpeng Island.osm.pbf
# CGN Rudong Demonstration.osm.pbf
# DanTysk.yaml
# Deutsche Bucht.osm.pbf
# Dogger Bank A.yaml
# Dudgeon.yaml
# East Anglia ONE.yaml
# Fecamp.osm.pbf
# Galloper Inner.osm.pbf
# Gemini 1.osm.pbf
# Gemini 2.osm.pbf
# Global Tech 1.osm.pbf
# Gode Wind 1.yaml
# Greater Gabbard Inner.yaml
# Gwynt y Mor.yaml
# Hohe See.osm.pbf
# Horns Rev 1.yaml
# Horns Rev 2.yaml
# Horns Rev 3.yaml
# Hornsea One.yaml
# Hornsea Two West.yaml
# Humber Gateway.osm.pbf
# Kaskasi.osm.pbf
# Kriegers Flak A.osm.pbf
# Kriegers Flak B.osm.pbf
# Laoting Bodhi Island.osm.pbf
# Lillgrund.osm.pbf
# Lincs.osm.pbf
# London Array.yaml
# ...

# %% [markdown]
# Check if the file data is available and then instantial WindFarmNetwork (using .from_yaml or .from_pbf depending on the file format)

# %%
Path('../../optiwindnet/data/Seagreen.osm.pbf').exists()
# Out:
# True

# %%
file_path = '../../optiwindnet/data/Seagreen.osm.pbf'
wfn = WindFarmNetwork.from_pbf(filepath=file_path, cables=7)

# %%
# set Matplotlib option to generate inline SVG
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
plt.rcParams['svg.fonttype'] = 'none'

# plot location
wfn.plot_location()
# Out:
# <Axes: >

# %%
wfn.plot_location(node_tag='label')
# Out:
# <Axes: >
