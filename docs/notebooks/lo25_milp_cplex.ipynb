# %% [markdown]
# ## CPLEX

# %% [markdown]
# **Concepts:** [Exact optimization](../routers.md#exact-optimization) **Reference:** [MILP Solvers](../reference/solvers.md) **Network/Router API:** [🎯 MILPRouter](hi23_milp.ipynb)

# %% [markdown]
# Solving the MILP model with IBM ILOG CPLEX — commercial, with an academic license available. The approach and the full solver roster are described in [Exact optimization](../routers.md#exact-optimization), the model options in [Model options](../routers.md#model-options), and the installation steps in [Install](../install.md).

# %%
from optiwindnet.heuristics import constructor
from optiwindnet.importer import load_repository
from optiwindnet.interarraylib import G_from_S
from optiwindnet.mesh import make_planar_embedding
from optiwindnet.MILP import ModelOptions, solver_factory
from optiwindnet.svg import svgplot

# %% [markdown]
# ### Initialize Race Bank 2

# %%
locations = load_repository()

# %%
L = locations.race
capacity = 5

# %%
svgplot(L)
# Out:
# <SvgRepr[race]: name=Race Bank; T=91; R=2; 3730 chars>

# %% [markdown]
# ### Optimize Race Bank 2

# %%
P, A = make_planar_embedding(L)

# %% [markdown]
# Initial heuristic solution to warm-start the solver:

# %%
Sʹ = constructor(A, capacity=capacity)
Gʹ = G_from_S(Sʹ, A)
svgplot(Gʹ)
# Out:
# <SvgRepr[race]: name=Race Bank; T=91; R=2; capacity=5; topology=branched
#  feeders = 13|9; C = 0; D = 0; Σλ = 93_901 m; 8872 chars>

# %%
solver = solver_factory('cplex')

# %%
solver.set_problem(
    P,
    A,
    capacity=Sʹ.graph['capacity'],
    model_options=ModelOptions(
        topology='branched',
        feeder_route='segmented',
        feeder_limit='unlimited',
    ),
    warmstart=Sʹ,
)

# %%
solver.solve(
    mip_gap=0.002,
    time_limit=20,
    verbose=True,
)
# Out:
# Version identifier: 22.2.0.0 | 2026-05-04 | 5dff98e58
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Parallel                                -1
# CPXPARAM_Emphasis_MIP                            4
# CPXPARAM_TimeLimit                               20
# CPXPARAM_MIP_Tolerances_MIPGap                   0.002
# 1 of 1 MIP starts provided solutions.
# MIP start 'm1' defined initial solution with objective 93901.0670.
# Tried aggregator 1 time.
# MIP Presolve eliminated 366 rows and 0 columns.
# MIP Presolve modified 1038 coefficients.
# Reduced MIP has 2736 rows, 2076 columns, and 9870 nonzeros.
# Reduced MIP has 1038 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (7.46 ticks)
# Probing time = 0.00 sec. (2.89 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 2736 rows, 2076 columns, and 9870 nonzeros.
# Reduced MIP has 1038 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (5.83 ticks)
# Probing time = 0.00 sec. (2.83 ticks)
# Clique table members: 476.
# MIP emphasis: hidden feasible solutions.
# MIP search method: dynamic search.
# Parallel mode: opportunistic, using up to 16 threads.
# Root relaxation solution time = 0.03 sec. (33.64 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                        93901.0670        0.0000           100.00%
#       0     0    85779.2773    69    93901.0670    85779.2773     1396    8.65%
# *     0+    0                        90445.0696    85779.2773             5.16%
#       0     0    86312.2940   116    90445.0696     Cuts: 115     1622    4.57%
#       0     0    86525.1600   138    90445.0696     Cuts: 153     1791    4.33%
# *     0+    0                        89179.7320    86525.1600             2.98%
#       0     0    86666.3392   137    89179.7320     Cuts: 128     1918    2.82%
#       0     0    86714.5199   143    89179.7320      Cuts: 63     2012    2.76%
#       0     0    86731.1736   128    89179.7320      Cuts: 88     2083    2.75%
# Detecting symmetries...
#       0     0    86744.3501   160    89179.7320      Cuts: 40     2143    2.73%
#       0     0    86749.1250   156    89179.7320      Cuts: 40     2192    2.73%
#       0     0    86751.6465   154    89179.7320      Cuts: 19     2231    2.72%
# *     0+    0                        89128.4556    86751.6465             2.67%
# *     0+    0                        88994.5843    86751.6465             2.52%
# *     0+    0                        88961.7539    86751.6465             2.48%
# *     0+    0                        88735.4760    86751.6465             2.24%
# *     0+    0                        88429.6950    86751.6465             1.90%
# *     0+    0                        88111.6761    86751.6465             1.54%
#       0     0  -1.00000e+75     0    88111.6761    86751.6465     2231    1.54%
# Detecting symmetries...
#       0     2    86751.6465   154    88111.6761    86785.6751     2231    1.50%
# Elapsed time = 1.53 sec. (913.22 ticks, tree = 0.02 MB, solutions = 9)
#     159    51    87382.9381   114    88111.6761    86836.3344     7894    1.45%
#     491   260    87902.7874    92    88111.6761    86836.6197    32205    1.45%
#     910   572    87030.3451   139    88111.6761    86869.6595    68127    1.41%
#    1314   770        cutoff          88111.6761    86869.6595    89917    1.41%
# *  1339   824      integral     0    87950.7892    86869.6595    95757    1.23%
#    1768   910    87864.2311    95    87950.7892    86895.1126   124144    1.20%
#    2333  1158    87798.2914    83    87950.7892    86919.9643   148891    1.17%
#    2896  1600    87111.5284   137    87950.7892    86971.6764   180309    1.11%
#    3482  1827    87572.8157   114    87950.7892    87074.0404   193937    1.00%
#    4034  2175    87450.0059   153    87950.7892    87088.7257   212581    0.98%
# *  4583+ 2751                        87802.9883    87104.5478             0.80%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 2 times.
# MIP Presolve eliminated 422 rows and 392 columns.
# MIP Presolve modified 170 coefficients.
# Aggregator did 4 substitutions.
# Reduced MIP has 2310 rows, 1680 columns, and 8020 nonzeros.
# Reduced MIP has 838 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.47 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 6 rows and 3 columns.
# Reduced MIP has 2304 rows, 1677 columns, and 8008 nonzeros.
# Reduced MIP has 838 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (5.20 ticks)
# Represolve time = 0.03 sec. (24.80 ticks)
#    4595     0    86863.0676   171    87802.9883      Cuts: 86   269087    0.78%
#    4595     0    86909.0374   178    87802.9883     Cuts: 104   269307    0.78%
#    4595     0    86927.5099   182    87802.9883     Cuts: 106   269466    0.78%
#    4595     0    86946.0765   182    87802.9883      Cuts: 85   269610    0.78%
#    4595     0    86964.7580   184    87802.9883     Cuts: 108   269723    0.78%
#    4595     0    86981.6040   180    87802.9883      Cuts: 72   269838    0.78%
#    4595     0    86986.5937   174    87802.9883      Cuts: 49   269907    0.78%
#    4595     0    86994.8177   185    87802.9883      Cuts: 51   269984    0.78%
#    4595     2    86994.8177   185    87802.9883    87222.4467   269984    0.66%
# Elapsed time = 9.61 sec. (6459.92 ticks, tree = 0.02 MB, solutions = 11)
#    4843    83    87666.8481   128    87802.9883    87222.4467   289278    0.66%
#    5692   133        cutoff          87802.9883    87222.4467   318610    0.66%
#
# GUB cover cuts applied:  4
# Flow cuts applied:  43
# Mixed integer rounding cuts applied:  140
# Lift and project cuts applied:  60
# Gomory fractional cuts applied:  11
#
# Root node processing (before b&c):
#   Real time             =    1.36 sec. (911.79 ticks)
# Parallel b&c, 16 threads:
#   Real time             =   10.75 sec. (7901.71 ticks)
#   Sync time (average)   =    1.14 sec.
#   Wait time (average)   =    0.01 sec.
#                           ------------
# Total (root+branch&cut) =   12.11 sec. (8813.49 ticks)
# SolutionInfo(runtime=12.114213943481445, bound=87627.41566279474, objective=87802.98827572021, relgap=0.0019996200171927825, termination='optimal')

# %%
S, G = solver.get_solution()

# %%
svgplot(G)
# Out:
# <SvgRepr[race]: name=Race Bank; T=91; R=2; capacity=5; topology=branched
#  feeders = 10|9; C = 1; D = 0; Σλ = 87_803 m; 8822 chars>
