# %% [markdown]
# # **Routing Cables in a Large Wind Farm with Complex Geometry**
#
# In this notebook, we demonstrate how to use `optiwindnet` to route cables for a large wind farm with 122 turbines and 2 substations. The site features a concave cable-laying area and includes an internal obstacle.
#
# The added geometric complexity and increased scale have negligible impact on solving time, as they do not increase the number of variables in the MILP optimization model.

# %%
from optiwindnet.api import WindFarmNetwork, Heuristic, MILP, ModelOptions, load_repository

# %%
# Display figures as SVG in Jupyter notebooks
# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# ### Solvers

# %% [markdown]
# Using a *MILP* solver can produce better solutions respect to *Heuristics* and *Metaheuristics*. This notebook uses *COIN-OR CBC*, but examples for other solvers (*gurobi, cplex, ortools, scip, highs*) can be found in the *MILP* notebooks.
#
# > Gurobi and IBM ILOG CPLEX are comercial solvers (academic license available). Google's OR-Tools, COIN-OR CBC, SCIP and HiGHS are open-source software.

# %% [markdown]
# ### Load input data
#
# In this example, the `load_repository()` functionality is used to load a prebuilt *Networkx.Graph*. For more details on this functionality look into the notebook about [Load repositories containing location data](api_02-load-repositories.ipynb).

# %%
locations = load_repository()

# %% [markdown]
# The example location from <https://onlinelibrary.wiley.com/doi/abs/10.1049/rpg2.12593> (Taylor_2023) provides suitable specifications for our purpose—a large wind farm with multiple substations and complex geometry.

# %%
wfn = WindFarmNetwork(L=locations.taylor_2023, cables=8)

# %% [markdown]
# > Note: To view output plots, trust this notebook first.

# %%
wfn.plot_location()
# Out:
# <Axes: >

# %% [markdown]
# There are two options for generating an initial solution to warm-start the MILP solver:
# - heuristic: `EW_presolver()`
# - meta-heuristic: `hgs_multiroot()`
#
# **EW_presolver** has the downside of not limiting the number of feeders, thus the model to be warm-started must also have an unlimited number of feeders. This is usually not a problem, as most cable route sets produced by the MILP solver use the minimum number of feeders or only one more than the minimum.

# %% [markdown]
# ### Generate the warm-start solution
#
# To generate a warm-start solution, simply run `wfn.optimize()` with the desired solver e.g.:
#
# ```python
# wfn.optimize(router=router_warmstart)
# ```
#
# In this example, we use `EW_presolver` to warm-start the optimization model. Alternatively, `HGS_multiroot()` can be used for the same purpose.
#
# The resulting solution is stored within the `wfn` object. The next time `wfn.optimize()` is called, the stored solution (`S` which contains *selected-links*) will be reused as a warm start—provided that the selected router supports warm-starting.

# %%
router_warmstart = Heuristic(solver='Esau_Williams')
res_warmstart= wfn.optimize(router=router_warmstart)

# %% [markdown]
# ### Visualizing the warm-start solution

# %% [markdown]
# `S` can be visualized using `wfn.plot_selected_links()`.
#
# > For a detailed explanation and visuals about different graphs and plots in OptiWindNet:
# > - look into the notebook about [Plotting](api_05-Plotting.ipynb)
# > - read this paper:**To be added: \[link to paper]**

# %%
wfn.plot_selected_links()
# Out:
# <Axes: >

# %% [markdown]
# ### Create MILP model and optimize it using COIN-OR Branch and Cut (CBC)

# %% [markdown]
# When initializing a MILP solver three arguments are required to be given:
# - solver name
# - time limit
# - gap

# %%
router_milp = MILP(solver_name='cbc', time_limit=300, mip_gap=0.005)

# %% [markdown]
# After initializing the router, OptiWindNet sets a set of default options internally.
# We can view the router options that were modified to match OptiWindNet’s preferred values using:
#
# ```python
# router.optiwindnet_default_options
# ```
#
# This attribute only reflects the options explicitly modified by OptiWindNet during initialization. MILP solvers typically support a much larger set of configurable options, which we can also adjust separately.
# For example, in the case of the CBC solver, we can refer to its full list of options here:
# [http://www.decom.ufop.br/haroldo/files/cbcCommandLine.pdf](http://www.decom.ufop.br/haroldo/files/cbcCommandLine.pdf)
#
# > **Note:** Modifying any of the options originally set by OptiWindNet will not change the values stored in `optiwindnet_default_options`. However, the updated values will be used when solving the optimization problem.

# %%
router_milp.optiwindnet_default_options
# Out:
# {'threads': 8,
#  'timeMode': 'elapsed',
#  'nodeStrategy': 'downFewest',
#  'Dins': 'on',
#  'VndVariableNeighborhoodSearch': 'on',
#  'Rens': 'on',
#  'Rins': 'on',
#  'pivotAndComplement': 'off',
#  'proximitySearch': 'off',
#  'gomoryCuts': 'on',
#  'mixedIntegerRoundingCuts': 'on',
#  'flowCoverCuts': 'on',
#  'cliqueCuts': 'off',
#  'twoMirCuts': 'off',
#  'knapsackCuts': 'off',
#  'probingCuts': 'off',
#  'zeroHalfCuts': 'off',
#  'liftAndProjectCuts': 'off',
#  'residualCapacityCuts': 'off'}

# %% [markdown]
# Similarly, we can view the default values used for the optimization model via:
#
# ```python
# router.model_options
# ```
#
# These `model_options` are not specific to the solver, they define settings related to the structure and behavior of the optimization model itself, rather than the router or solver configuration.

# %%
router_milp.model_options
# Out:
# {'topology': <Topology.BRANCHED: 'branched'>,
#  'feeder_route': <FeederRoute.SEGMENTED: 'segmented'>,
#  'feeder_limit': <FeederLimit.UNLIMITED: 'unlimited'>,
#  'balanced': False,
#  'max_feeders': 0}

# %% [markdown]
# A help for model options can be access via:
#
# ```python
# ModelOptions.help()
# ```

# %%
ModelOptions.help()
# Out:
# topology in {"radial", "branched", "branched"} default: branched
#     Set the topology of subtrees in the solution.
#
# feeder_route in {"straight", "segmented", "segmented"} default: segmented
#     If feeder routes must be "straight" or can be detoured ("segmented").
#
# feeder_limit in {"unlimited", "specified", "minimum", "min_plus1", "min_plus2", "min_plus3", "unlimited"} default: unlimited
#     Whether to limit the maximum number of feeders, if set to "specified", additional kwarg "max_feeders" must be given.
#
# balanced [bool] default: False
#     Whether to enforce balanced subtrees (subtree loads differ at most by one unit).
#
# max_feeders [int] default: 0
#     Maximum number of feeders (used only if <feeder_limit = "specified">)

# %% [markdown]
# Solver options—including those set by OptiWindNet as well as additional configurable parameters—can be modified by creating a **dictionary** and passing it to the router. The same approach applies to **model options**.

# %%
solver_options=dict( # these are in addition to the default solver.options
        # if repeatable results are desired, set the seed
        RandomCbcSeed=1234567,
        # CBC works better if the number threads is set to the number of physical cores
        threads=6,
    )

model_options = ModelOptions(
                        topology='branched',
                        feeder_limit='unlimited',
                        feeder_route='segmented',
                    )

router_milp = MILP(solver_name='cbc', time_limit=300, mip_gap=0.005, solver_options=solver_options, model_options=model_options)

# %% [markdown]
# Run optimizatin with MILP router

# %%
# Set logging level to INFO to display messages about warm-starting and solver options
import logging
logging.basicConfig(level=logging.INFO)

# run optimization with the milp router (Set verbose=True to display messages about solver progress)
res = wfn.optimize(router=router_milp, verbose=True)
# Out:
# INFO:optiwindnet.api: S is not None and the model is warmed up with the available S.
# INFO:optiwindnet.MILP.pyomo:>>> cbc solver options <<<
# Dins: 'on'
# RandomCbcSeed: 1234567
# Rens: 'on'
# Rins: 'on'
# VndVariableNeighborhoodSearch: 'on'
# cliqueCuts: 'off'
# flowCoverCuts: 'on'
# gomoryCuts: 'on'
# knapsackCuts: 'off'
# liftAndProjectCuts: 'off'
# mixedIntegerRoundingCuts: 'on'
# nodeStrategy: 'downFewest'
# pivotAndComplement: 'off'
# probingCuts: 'off'
# proximitySearch: 'off'
# ratioGap: 0.005
# residualCapacityCuts: 'off'
# seconds: 300
# threads: 6
# timeMode: 'elapsed'
# twoMirCuts: 'off'
# zeroHalfCuts: 'off'
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Jan  1 1970
#
# command line - C:\my_program_files\cbc\bin\cbc.exe -threads 6 -timeMode elapsed -nodeStrategy downFewest -Dins on -VndVariableNeighborhoodSearch on -Rens on -Rins on -pivotAndComplement off -proximitySearch off -gomoryCuts on -mixedIntegerRoundingCuts on -flowCoverCuts on -cliqueCuts off -twoMirCuts off -knapsackCuts off -probingCuts off -zeroHalfCuts off -liftAndProjectCuts off -residualCapacityCuts off -RandomCbcSeed 1234567 -seconds 300 -ratioGap 0.005 -printingOptions all -import C:\Users\amia\AppData\Local\Temp\tmphrjyuh18.pyomo.lp -mipstart \Users\amia\AppData\Local\Temp\tmp8wd16a13.cbc.soln -stat=1 -solve -solu C:\Users\amia\AppData\Local\Temp\tmphrjyuh18.pyomo.soln (default strategy 1)
# threads was changed from 0 to 6
# Option for timeMode changed from cpu to elapsed
# Option for nodeStrategy changed from fewest to downfewest
# Option for Dins changed from off to on
# Option for VndVariableNeighborhoodSearch changed from off to on
# Option for Rens changed from off to on
# Option for gomoryCuts changed from ifmove to on
# Option for mixedIntegerRoundingCuts changed from ifmove to on
# Option for flowCoverCuts changed from ifmove to on
# Option for cliqueCuts changed from ifmove to off
# Option for twoMirCuts changed from root to off
# Option for knapsackCuts changed from ifmove to off
# Option for probingCuts changed from on to off
# Option for zeroHalfCuts changed from ifmove to off
# randomCbcSeed was changed from -1 to 1234567
# seconds was changed from 1e+100 to 300
# ratioGap was changed from 0 to 0.005
# Option for printingOptions changed from normal to all
# opening mipstart file \Users\amia\AppData\Local\Temp\tmp8wd16a13.cbc.soln.
# MIPStart values read for 244 variables.
# Presolve 4320 (-2) rows, 2895 (-1) columns and 14884 (-1444) elements
# Statistics for presolved model
# Original problem has 2896 integers (1448 of which binary)
# Presolved problem has 2895 integers (1447 of which binary)
# ==== 1448 zero objective 841 different
# ==== absolute objective values 841 different
# ==== for integers 1448 zero objective 841 different
# ==== for integers absolute objective values 841 different
# ===== end objective counts
#
#
# Problem has 4320 rows, 2895 columns (1447 with objective) and 14884 elements
# Column breakdown:
# 0 of type 0.0->inf, 1448 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 1447 of type 0.0->1.0
# Row breakdown:
# 0 of type E 0.0, 243 of type E 1.0, 0 of type E -1.0,
# 1 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 1 of type G other, 2895 of type L 0.0, 1056 of type L 1.0,
# 124 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 104286 - 0.06 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 530 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 530 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 220 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 122 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3888 rows, 2896 columns (2896 integer (1448 of which binary)) and 15734 elements
# Cbc0045I MIPStart provided solution with cost 113017
# Cbc0012I Integer solution of 113017.26 found by Reduced search after 0 iterations and 0 nodes (0.28 seconds)
# Cbc0038I Full problem 3889 rows 2896 columns, reduced to 251 rows 145 columns
# Cbc0038I Full problem 3889 rows 2896 columns, reduced to 251 rows 145 columns
# Cbc0038I Full problem 3889 rows 2896 columns, reduced to 251 rows 145 columns
# Cbc0038I Full problem 3888 rows 2896 columns, reduced to 425 rows 234 columns
# Cbc0038I Full problem 3889 rows 2896 columns, reduced to 291 rows 180 columns
# Cbc0038I Full problem 3889 rows 2896 columns, reduced to 291 rows 180 columns
# Cbc0038I Full problem 3889 rows 2896 columns, reduced to 291 rows 180 columns
# Cbc0031I 102 added rows had average density of 109.90196
# Cbc0013I At root node, 102 cuts changed objective from 104286.37 to 104858.81 in 17 passes
# Cbc0014I Cut generator 0 (Gomory) - 186 row cuts average 373.7 elements, 0 column cuts (0 active)  in 0.424 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (MixedIntegerRounding2) - 1 row cuts average 283.0 elements, 0 column cuts (0 active)  in 0.068 seconds - new frequency is 4
# Cbc0014I Cut generator 2 (FlowCover) - 181 row cuts average 17.5 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 113017.26 best solution, best possible 104858.81 (1.65 seconds)
# Cbc0010I After 100 nodes, 62 on tree, 113017.26 best solution, best possible 104872.64 (10.43 seconds)
# Cbc0010I After 200 nodes, 117 on tree, 113017.26 best solution, best possible 104872.64 (13.40 seconds)
# Cbc0010I After 300 nodes, 169 on tree, 113017.26 best solution, best possible 104872.64 (15.28 seconds)
# Cbc0010I After 400 nodes, 212 on tree, 113017.26 best solution, best possible 104872.64 (17.09 seconds)
# Cbc0010I After 500 nodes, 267 on tree, 113017.26 best solution, best possible 104872.64 (18.72 seconds)
# Cbc0010I After 600 nodes, 317 on tree, 113017.26 best solution, best possible 104872.64 (20.23 seconds)
# Cbc0010I After 700 nodes, 367 on tree, 113017.26 best solution, best possible 104872.64 (21.40 seconds)
# Cbc0010I After 800 nodes, 401 on tree, 113017.26 best solution, best possible 104872.64 (22.51 seconds)
# Cbc0010I After 900 nodes, 431 on tree, 113017.26 best solution, best possible 104872.64 (23.35 seconds)
# Cbc0010I After 1000 nodes, 466 on tree, 113017.26 best solution, best possible 104872.64 (24.12 seconds)
# Cbc0010I After 1100 nodes, 508 on tree, 113017.26 best solution, best possible 104872.64 (25.06 seconds)
# Cbc0030I Thread 2 used 4487 times,  waiting to start 2.8674772,  28205 locks, 3.5064061 locked, 0.66207147 waiting for locks
# Cbc0030I Thread 3 used 4364 times,  waiting to start 2.916187,  27469 locks, 3.9457705 locked, 0.77098417 waiting for locks
# Cbc0030I Thread 4 used 4145 times,  waiting to start 3.0107718,  26117 locks, 3.4505048 locked, 0.64496398 waiting for locks
# Cbc0030I Thread 5 used 4489 times,  waiting to start 3.6959658,  28206 locks, 3.8109999 locked, 0.69171619 waiting for locks
# Cbc0030I Main thread 286.45254 waiting for threads,  52382 locks, 0.096455812 locked, 0.98410416 waiting for locks
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 111650.55 (best possible 105064.28), took 2583994 iterations and 26041 nodes (300.53 seconds)
# Cbc0032I Strong branching done 39644 times (1212599 iterations), fathomed 717 nodes and fixed 2010 variables
# Cbc0035I Maximum depth 230, 297727 variables fixed on reduced cost
# Cuts at root node changed objective from 104286 to 104859
# Gomory was tried 10764 times and created 5668 cuts of which 0 were active after adding rounds of cuts (112.592 seconds)
# MixedIntegerRounding2 was tried 10103 times and created 5578 cuts of which 0 were active after adding rounds of cuts (54.065 seconds)
# FlowCover was tried 10765 times and created 73110 cuts of which 0 were active after adding rounds of cuts (40.731 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                111650.55388855
# Lower bound:                    105064.278
# Gap:                            0.06
# Enumerated nodes:               26041
# Total iterations:               2583994
# Time (CPU seconds):             300.58
# Time (Wallclock seconds):       300.58
#
# Total time (CPU seconds):       300.79   (Wallclock seconds):       300.79
# WARNING:pyomo.core:Loading a SolverResults object with an 'aborted' status, but containing a solution
# INFO:optiwindnet.MILP.pyomo:>>> Solution <<<
# SolutionInfo(runtime=300.79, bound=105064.28, objective=111650.55388855, relgap=0.058990069096517384, termination='maxTimeLimit')

# %% [markdown]
# Terse link of the final layout is returned as output of `wfn.optimize()`. If not assigned to a variable (e.g. res), it can be easily accessed via `wfn.terse_links()`.

# %%
res
# Out:
# array([  6,   0,   1,   4,  10,  11,   5,  12,   7,  10,  18,  19,  20,
#         14,   7,  23,  15,   9,  27,  28,  29,  14,  23,  24,  25,  26,
#         36,  37,  -2,  -2,  -2,  41,  33,  34,  35,  45,  -2,  -2,  -2,
#         -2,  -2,  52,  53,  44,  55,  46,  56,  48,  38,  39,  40,  50,
#         64,  54,  43,  67,  68,  69,  48,  49,  59,  51,  61,  62,  65,
#         77,  54,  -1,  -1,  70,  58,  70,  85,  60,  73,  63,  75,  78,
#         79,  -1,  -1,  -1,  81,  82,  83,  84,  85,  74,  87,  90,  99,
#         -1,  -1,  -1,  93,  94,  95,  86, 107,  91,  99,  -1,  92, 110,
#        103,  96, 105, 106, 100, 101, 102, 117, 104, 112, 113, 100, 109,
#        116, 117, 118, 115, 117])

# %% [markdown]
# ### Plot the optimized network graph
#
# >Note: The cable cost is equal to the cable length in this example because no cable price data was provided. As a result, OptiWindNet assigns a unit cost (1.0) per unit length by default.

# %%
wfn.plot()
# Out:
# <Axes: >
